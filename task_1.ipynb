# %%
from __future__ import division
from __future__ import print_function

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from IPython import display
from sklearn import datasets, preprocessing
import tensorflow as tf

# %%
(X, y) = datasets.make_circles(n_samples=1024, shuffle=True, noise=0.2, factor=0.4)
ind = np.logical_or(y==1, X[:,1] > X[:,0] - 0.5)
X = X[ind,:]
X = preprocessing.scale(X)
y = y[ind]
y = 2*y - 1
plt.scatter(X[:, 0], X[:, 1], cmap=plt.cm.Paired, c=y, edgecolors='black')

plt.show()

# %%
h = 0.01
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
def visualize(X, y, w, loss, n_iter):
    plt.clf()
    plt.figure(figsize=(20, 8))
    Z = classify(np.c_[xx.ravel(), yy.ravel()], w)
    Z = Z.reshape(xx.shape)
    plt.subplot(1,2,1)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='black')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.subplot(1,2,2)
    plt.plot(loss)
    plt.grid()
    ymin, ymax = plt.ylim()
    plt.ylim(0, ymax)
    display.clear_output(wait=True)
    display.display(plt.gcf())

# %% [markdown]
# **Your task starts here**
#
# First, let's write a function that predicts class for given X.
#
# Since the problem above isn't linearly separable, we add quadratic features to the classifier. This transformation is implemented in the __expand__ function.
#
# __Don't forget to expand X inside classify and other functions__
#
# Sample classification should not be much harder than computation of sign of dot product.

# %%
def expand(X):
    X_ = tf.zeros((X.shape[0], 6))
    X0 = tf.transpose(tf.gather(tf.transpose(X), [0]))
    X1 = tf.transpose(tf.gather(tf.transpose(X), [1]))
    X_ = tf.concat([X, X ** 2, X0 * X1, tf.ones(shape=(X.shape[0], 1))], axis=1)
    return X_

def classify(X, w):
    """
    Given feature matrix X [n_samples,2] and weight vector w [6],
    return an array of +1 or -1 predictions
    """
    ans = tf.transpose(tf.sign(tf.matmul(expand(X.astype(np.float32)), w[np.newaxis].T)))
    with tf.Session() as sess:
        return ans.eval()

# %% [markdown]
# The loss you should try to minimize is the Hinge Loss:
#
# $$ L =  {1 \over N} \sum_{i=1}^N max(0,1-y_i \cdot  w^T x_i) $$

# %%
def compute_loss(X, y, w):
    """
    Given feature matrix X [n_samples,2], target vector [n_samples] of +1/-1,
    and weight vector w [6], compute scalar loss function using formula above.
    """
    x = expand(X)
    loss = tf.squeeze(1 - tf.multiply(y, tf.transpose(tf.matmul(expand(X), tf.transpose(w)))), name="loss")
    out = tf.reduce_mean(tf.maximum(loss, tf.zeros(X.shape[0])))
    
    return out
    
def compute_grad(X, y, w):
    """
    Given feature matrix X [n_samples,2], target vector [n_samples] of +1/-1,
    and weight vector w [6], compute vector [6] of derivatives of L over each weights.
    """
    x = expand(X)
    loss = tf.squeeze(1 - tf.transpose(y) * tf.matmul(x, tf.transpose(w)), name="loss")
    d = tf.where(loss > 0, -x * tf.transpose(y), tf.zeros(x.shape))
    dL = tf.reduce_mean(d, axis=0, name="dL")
    
    return dL

# %% [markdown]
# ### Training
# Find an optimal learning rate for gradient descent for given batch size.
#
# You can see the example of correct output below this cell before you run it.
#
# **Don't change the batch size!**

# %%
batch_size = 4

X_in = tf.placeholder(tf.float32, shape=X.shape, name="X_in")
y_in = tf.placeholder(tf.float32, shape=(1, len(y)), name="y_in")
w_in = tf.placeholder(tf.float32, shape=(1, 6), name="w_in")

Xb = tf.placeholder(tf.float32, shape=(batch_size, X.shape[1]), name="Xb")
yb = tf.placeholder(tf.float32, shape=(1, batch_size), name="yb")

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %% [markdown]
# Implement gradient descent with momentum and test it's performance for different learning rate and momentum values.

# %%
alpha = 0.25
assign_w = tf.assign(w, w - alpha * gradn)

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
        
    visualize(X, y, w.eval(sess)[0], loss, n_iter)
    plt.clf()

# %%
batch_size = 4

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %%
alpha = 0.25 # learning rate
mu    = 0.4 # momentum

v = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
assign_v = tf.assign(v, mu * v + alpha * gradn)
assign_w = tf.assign(w, w - assign_v)

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
    visualize(X, y, w.eval().squeeze(), loss, n_iter)
    plt.clf()

# %% [markdown]
# Same task but for Nesterov's accelerated gradient:

# %%
batch_size = 4

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %%
alpha = 0.25
mu = 0.4

v = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
gradn = compute_grad(Xb, yb, w - mu * v)
assign_v = tf.assign(v, mu * v + alpha * gradn)
assign_w = tf.assign(w, w - assign_v)

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
    visualize(X, y, w.eval().squeeze(), loss, n_iter)
    plt.clf()

# %% [markdown]
# Same task but for AdaGrad:

# %%
batch_size = 4

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
d = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %%
alpha = 0.35 # learning rate
eps = 1e-8  # A small constant for numerical stability

assign_d = tf.assign(d, d + gradn ** 2)
assign_w = tf.assign(w, w - alpha * gradn / tf.sqrt(assign_d + eps))

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
    visualize(X, y, w.eval().squeeze(), loss, n_iter)
    plt.clf()

# %% [markdown]
# Same task but for AdaDelta:

# %%
batch_size = 4

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
d = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %%
alpha = 0.1
beta = 0.9
eps = 1e-8

assign_d = tf.assign(d, beta * d + (1 - beta) * (gradn ** 2))
assign_w = tf.assign(w, w - alpha * gradn / tf.sqrt(assign_d + eps))

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
    visualize(X, y, w.eval().squeeze(), loss, n_iter)
    plt.clf()

# %% [markdown]
# Same task for Adam algorithm. You can start with beta = 0.9 and mu = 0.999

# %%
batch_size = 4

w = tf.Variable([[1, 0, 0, 0, 0, 0]], dtype=tf.float32)
v = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
d = tf.Variable([[0, 0, 0, 0, 0, 0]], dtype=tf.float32)
lossn = compute_loss(X_in, y_in, w)
gradn = compute_grad(Xb, yb, w)

n_iter = 50
loss = np.zeros(n_iter)

# %%
alpha = 0.25 # learning rate
beta = 0.9  # (beta1 coefficient in original paper) exponential decay rate for the 1st moment estimates
mu   = 0.9  # (beta2 coefficient in original paper) exponential decay rate for the 2nd moment estimates
eps = 1e-8  # A small constant for numerical stability

assign_v = tf.assign(v, mu * v + (1 - mu) * gradn)
assign_c = tf.assign(d, beta * d + (1 - beta) * (gradn ** 2))
assign_w = tf.assign(w, w - alpha * assign_v / tf.sqrt(assign_c + eps))

plt.figure(figsize=(12,5))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(n_iter):
        ind = random.sample(range(X.shape[0]), batch_size)
        loss[i] = sess.run(lossn, feed_dict={X_in: X,y_in: y.reshape(1, len(y))})
        sess.run(assign_w, feed_dict={Xb: X[ind, :],yb: y[ind].reshape(1, 4)})
    visualize(X, y, w.eval().squeeze(), loss, n_iter)
    plt.clf()
